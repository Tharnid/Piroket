# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("astronauts.csv")

# %%
df.head(2)
# Out:
#               Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0  Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1   Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
#
#                                           Alma Mater  Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...              Geology
# 1   Montana State University; University of Colorado  Engineering Physics
#
#   Graduate Major Military Rank Military Branch  Space Flights  \
# 0        Geology           NaN             NaN              2
# 1  Solar Physics           NaN             NaN              1
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0               3307            2              13.0
# 1                190            0               0.0
#
#                                  Missions Death Date Death Mission
# 0  STS-119 (Discovery), ISS-31/32 (Soyuz)        NaN           NaN
# ...

# %%
df.sample(3)
# Out:
#                        Name    Year  Group    Status Birth Date  Birth Place  \
# 60   Christopher J. Cassidy  2004.0   19.0    Active   1/4/1970    Salem, MA
# 309   Frederick W. Sturckow  1995.0   15.0   Retired  8/11/1961  La Mesa, CA
# 278         Stuart A. Roosa  1966.0    5.0  Deceased  8/16/1933  Durango, CO
#
#     Gender                               Alma Mater       Undergraduate Major  \
# 60    Male                    US Naval Academy; MIT               Mathematics
# 309   Male  California Polytechnic State University    Mechanical Engineering
# 278   Male                   University of Colorado  Aeronautical Engineering
#
#         Graduate Major Military Rank            Military Branch  \
# 60   Ocean Engineering     Commander                    US Navy
# 309                NaN       Colonel  US Marine Corps (Retired)
# 278                NaN       Colonel     US Air Force (Retired)
#
#      Space Flights  Space Flight (hr)  Space Walks  Space Walks (hr)  \
# ...

# %%
df.sample(3, replace=True) # useful in bootstrap re-sampling
# Out:
#                      Name    Year  Group   Status Birth Date  \
# 195           Don L. Lind  1966.0    5.0  Retired  5/18/1930
# 290  Paul D. Scully-Power     NaN    NaN  Retired  5/28/1944
# 259        Gary E. Payton     NaN    NaN  Retired  6/20/1948
#
#            Birth Place Gender  \
# 195        Midvale, UT   Male
# 290  Sydney, Australia   Male
# 259    Rock Island, IL   Male
#
#                                             Alma Mater  \
# 195  University of Utah; University of California-B...
# 290                               University of Sydney
# 259            US Air Force Academy; Purdue University
#
#            Undergraduate Major                            Graduate Major  \
# 195                    Physics                           Nuclear Physics
# 290        Applied Mathematics                                       NaN
# 259  Astronautical Engineering  Astronautical & Aeronautical Engineering
#
# ...

# %%
df.info() # information on dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 357 non-null    object
#  1   Year                 330 non-null    float64
#  2   Group                330 non-null    float64
#  3   Status               357 non-null    object
#  4   Birth Date           357 non-null    object
#  5   Birth Place          357 non-null    object
#  6   Gender               357 non-null    object
#  7   Alma Mater           356 non-null    object
#  8   Undergraduate Major  335 non-null    object
#  9   Graduate Major       298 non-null    object
#  10  Military Rank        207 non-null    object
#  11  Military Branch      211 non-null    object
#  12  Space Flights        357 non-null    int64
#  13  Space Flight (hr)    357 non-null    int64
#  14  Space Walks          357 non-null    int64
# ...

# %%
df.shape
# Out:
# (357, 19)

# %%
# correlations between numeric columns
df.corr()
# Out:
#                        Year     Group  Space Flights  Space Flight (hr)  \
# Year               1.000000  0.980934       0.036420           0.331386
# Group              0.980934  1.000000      -0.011386           0.325683
# Space Flights      0.036420 -0.011386       1.000000           0.325233
# Space Flight (hr)  0.331386  0.325683       0.325233           1.000000
# Space Walks        0.210073  0.217891       0.257073           0.472796
# Space Walks (hr)   0.253502  0.261384       0.258642           0.454408
#
#                    Space Walks  Space Walks (hr)
# Year                  0.210073          0.253502
# Group                 0.217891          0.261384
# Space Flights         0.257073          0.258642
# Space Flight (hr)     0.472796          0.454408
# Space Walks           1.000000          0.985755
# Space Walks (hr)      0.985755          1.000000

# %%
df["Year"].value_counts()
# Out:
# 1996.0    35
# 1978.0    35
# 1998.0    25
# 1990.0    23
# 1966.0    19
# 1995.0    19
# 1980.0    19
# 1992.0    19
# 1984.0    18
# 2000.0    17
# 1987.0    15
# 1963.0    14
# 1985.0    13
# 1967.0    11
# 2004.0    11
# 2009.0     9
# 1962.0     8
# 1969.0     7
# 1959.0     7
# 1965.0     6
# Name: Year, dtype: int64

# %%
# max in each column
df.max()
# Out:
# Name                 Yvonne D. Cagle
# Year                            2009
# Group                             20
# Status                       Retired
# Birth Date                  9/9/1952
# Birth Place              Yonkers, NY
# Gender                          Male
# Space Flights                      7
# Space Flight (hr)              12818
# Space Walks                       10
# Space Walks (hr)                  67
# dtype: object

# %% [markdown]
# # Recap
#
#     - head
#     - tail
#     - sample
#     - info
#     - describe
